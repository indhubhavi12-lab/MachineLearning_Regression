# %%
import pickle
from sklearn.linear_model import Linear_regression  # ✅ no space

# example: create and train a model
model = Linear_regression()  # ✅ no space
model.fit(X_train, y_train)  # make sure X_train and y_train are defined

# save the model
with open("MultiplelinearRegression.ipynb", 'wb') as file:  # safer to avoid spaces in filename
    pickle.dump(model, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4 # example: create and train a model
#       5 model = LinearRegression()  # ✅ no space
# ----> 6 model.fit(X_train, y_train)  # make sure X_train and y_train are defined
#       8 # save the model
#       9 with open("MultiplelinearRegression.ipynb", 'wb') as file:  # safer to avoid spaces in filename
#
# NameError: name 'X_train' is not defined
